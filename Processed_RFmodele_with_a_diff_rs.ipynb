# %%
import pandas as pd

X_train_clean = pd.read_csv('/content/X_train00.csv')
X_test_clean = pd.read_csv('/content/X_test00.csv')
y_train = pd.read_csv('/content/y_train00.csv')
y_test = pd.read_csv('/content/y_test00.csv')

# %%
# data = pd.read_excel('/content/finalSet.xlsx')
# data.head(3)

# %%
#@title Random State
RS = 42
RS2 = 42

# %%
#@title X and y definition
X = pd.concat([X_train_clean, X_test_clean], ignore_index=True)
y = pd.concat([y_train, y_test], ignore_index=True)

# %%
#@title Features Selection
Cols = [
    # 'age_at_diagnosis',
    # 'duree_propagation_jours',
    # 'Time_to_Treatment_Initiation',
    # 'antécédents_Familiaux',
    # 'tabac',
    # 'poids',
    # 'taille',
    # 'PS',
    # 'CA19-9',
    # 'ACE',
    # 'volume_colon',
    # 'nombre_metastaes',
    # '5FU',
    # 'capécitabine',
    # 'oxaliplatine',
    # 'irinotécan',
    # 'bévacizumab',
    # 'panitumumab',
    # 'cetuximab',
    # 'chimiothérapie_exclusive',
    # 'chirurgie',
    # 'maladie_evaluable',
    # 'maladie_meusurable',
    # 'tumor_size_total',
    'diff_E1_E2',
    'diff_E2_E3',
    'diff_E3_E4',
    # 'site_pelivien',
    # 'site_reins',
    # 'site_pancréas',
    # 'site_foie',
    # 'site_ovaires',
    # 'site_ovaire',
    # 'site_péritoine',
    # 'site_pelvienne',
    # 'site_adp',
    # 'site_prostate',
    # 'site_estomac',
    # 'site_thyroide',
    # 'site_pelvien',
    # 'site_oumon',
    # 'site_rectum',
    # 'site_poumons',
    # 'site_os',
    # 'site_rate',
    # 'site_poncréas',
    # 'site_gg',
    # 'site_abdomine',
    # 'site_péritoinerate',
    # 'site_sein',
    # 'site_thorax',
    # 'site_poumon',
    # 'genre_0.0',
    # 'genre_1.0',
    # 'sous_type_histologique_0.0',
    # 'sous_type_histologique_1.0',
    # 'sous_type_histologique_2.0',
    # 'sous_type_histologique_3.0',
    # 'sous_type_histologique_4.0',
    # 'grade_histologique_0.0',
    # 'grade_histologique_0.4',
    # 'grade_histologique_1.0',
    # 'grade_histologique_1.2',
    # 'grade_histologique_1.4',
    # 'grade_histologique_2.0',
    # 'grade_histologique_3.0',
    # 'tumeur_primitive_0.0',
    # 'tumeur_primitive_1.0',
    # 'tumeur_primitive_2.0',
    # 'tumeur_primitive_3.0',
    # 'tumeur_primitive_4.0',
    # 'RAS_0.0',
    # 'RAS_1.0',
    # 'RAS_2.0',
    # 'BRAF_0.0',
    # 'BRAF_1.0',
    # 'BRAF_2.0',
    # 'sites_métastatiques_0.0',
    # 'sites_métastatiques_1.0',
    # 'sites_métastatiques_2.0',
    # 'sites_métastatiques_3.0',
    # 'sites_métastatiques_4.0',
    # 'sites_métastatiques_5.0',
    # 'sites_métastatiques_6.0',
    # 'sites_métastatiques_7.0',
    # 'sites_métastatiques_8.0',
    # 'sites_métastatiques_9.0',
    # 'sites_métastatiques_10.0',
    # 'sites_métastatiques_11.0',
    # 'sites_métastatiques_12.0',
    # 'sites_métastatiques_13.0',
    # 'sites_métastatiques_14.0',
    # 'sites_métastatiques_15.0',
    # 'sites_métastatiques_16.0',
    # 'sites_métastatiques_17.0',
    # 'sites_métastatiques_18.0',
    # 'sites_métastatiques_19.0',
    # 'sites_métastatiques_20.0',
    # 'sites_métastatiques_21.0',
    # 'sites_métastatiques_22.0',
    # 'sites_métastatiques_23.0',
    # 'sites_métastatiques_24.0',
    # 'sites_métastatiques_25.0',
    # 'sites_métastatiques_26.0',
    # 'sites_métastatiques_27.0',
    # 'sites_métastatiques_28.0',
    # 'sites_métastatiques_29.0',
    # 'sites_métastatiques_30.0',
    # 'sites_métastatiques_31.0',
    # 'sites_métastatiques_32.0',
    # 'sites_métastatiques_33.0',
    # 'sites_métastatiques_34.0',
    # 'sites_métastatiques_35.0',
    # 'sites_métastatiques_36.0',
    # 'sites_métastatiques_37.0',
    # 'sites_métastatiques_38.0',
    # 'sites_métastatiques_39.0',
    # 'sites_métastatiques_40.0',
    # 'sites_métastatiques_41.0',
    # 'sites_métastatiques_42.0',
    # 'sites_métastatiques_43.0',
    # 'sites_métastatiques_44.0',
    # 'E1_res_0.0',
    # 'E1_res_0.4',
    # 'E1_res_0.6',
    # 'E1_res_1.0',
    # 'E1_res_1.4',
    # 'E1_res_1.6',
    # 'E1_res_2.0',
    'E2_res_0.0',
    'E2_res_0.2',
    'E2_res_0.6',
    'E2_res_0.8',
    'E2_res_1.0',
    'E2_res_1.2',
    'E2_res_1.4',
    'E2_res_1.6',
    'E2_res_1.8',
    'E2_res_2.0',
    'E3_res_0.0',
    'E3_res_0.8',
    'E3_res_1.0',
    'E3_res_1.4',
    'E3_res_1.6',
    'E3_res_1.8',
    'E3_res_2.0',
    'E3_res_2.2',
    'E3_res_2.4',
    'E3_res_3.0',
    'E4_res_0.0',
    'E4_res_0.8',
    'E4_res_1.0',
    'E4_res_1.2',
    'E4_res_1.4',
    'E4_res_1.6',
    'E4_res_1.8',
    'E4_res_2.0',
    'Statut_0.0',
    'Statut_1.0',
    'Statut_2.0',
    # 'organ_status_0.0',
    # 'organ_status_1.0',
    # 'organ_status_2.0',
    # 'organ_status_3.0'
]
X = X.drop(columns=Cols)

# %%
#@title train_tset split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RS, stratify=y)

# %%
#@title modelisation
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)


y_pred = model.predict(X_test)

# %%
#@title Evaluation : confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[8 2]
#  [2 8]]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80        10
#          1.0       0.80      0.80      0.80        10
#
#     accuracy                           0.80        20
#    macro avg       0.80      0.80      0.80        20
# weighted avg       0.80      0.80      0.80        20

# %%
# Confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
# #@title Cross validation
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=RS2)

# %%
# import numpy as np
# scores = cross_val_score(model, X_train_clean, y_train, cv=cv, scoring='f1_macro')
# print("F1 Macro Scores:", scores)
# print("Mean F1 Score:", np.mean(scores))
# print("Standard Deviation:", np.std(scores))

# %%
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=9)

# %%
# import numpy as np
# scores = cross_val_score(model, X_train_clean, y_train, cv=cv, scoring='f1_macro')
# print("F1 Macro Scores:", scores)
# print("Mean F1 Score:", np.mean(scores))
# print("Standard Deviation:", np.std(scores))

# %%
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=2001)
# import numpy as np
# scores = cross_val_score(model, X_train_clean, y_train, cv=cv, scoring='f1_macro')
# print("F1 Macro Scores:", scores)
# print("Mean F1 Score:", np.mean(scores))
# print("Standard Deviation:", np.std(scores))

# %%
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=2025)
# import numpy as np
# scores = cross_val_score(model, X_train_clean, y_train, cv=cv, scoring='f1_macro')
# print("F1 Macro Scores:", scores)
# print("Mean F1 Score:", np.mean(scores))
# print("Standard Deviation:", np.std(scores))

# %%
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# cv = StratifiedKFold(n_splits=7, shuffle=True, random_state=2025)
# import numpy as np
# scores = cross_val_score(model, X_train_clean, y_train, cv=cv, scoring='f1_macro')
# print("F1 Macro Scores:", scores)
# print("Mean F1 Score:", np.mean(scores))
# print("Standard Deviation:", np.std(scores))

# %%
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# import numpy as np
# import pandas as pd

# def search_best_cv_scores(model, X, y,
#                           random_states=[0, 1, 42, 2024, 2025],
#                           n_splits_list=[5, 7, 10],
#                           scoring='f1_macro'):
#     """
#     Teste plusieurs combinaisons de random_state et n_splits,
#     et retourne les meilleures performances de cross-validation.

#     Args:
#         model: le modèle sklearn
#         X: les features
#         y: les labels
#         random_states: liste de random_state à tester
#         n_splits_list: liste de n_splits à tester
#         scoring: métrique (par défaut f1_macro)

#     Returns:
#         pd.DataFrame trié par performance moyenne décroissante
#     """
#     results = []

#     for random_state in random_states:
#         for n_splits in n_splits_list:
#             cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
#             scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
#             results.append({
#                 'random_state': random_state,
#                 'n_splits': n_splits,
#                 'mean_score': np.mean(scores),
#                 'std_score': np.std(scores),
#                 'all_scores': scores
#             })

#     df_results = pd.DataFrame(results)
#     df_results.sort_values(by='mean_score', ascending=False, inplace=True)
#     return df_results

# %%
import warnings
from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np
import pandas as pd

def search_best_cv_scores(model, X, y,
                          random_states=[0, 1, 42, 2024, 2025],
                          n_splits_list=[5, 7, 10],
                          scoring='f1_macro'):
    """
    Teste plusieurs combinaisons de random_state et n_splits,
    et retourne les meilleures performances de cross-validation.
    Supprime les warnings pendant l'exécution.
    """
    results = []

    for random_state in random_states:
        for n_splits in n_splits_list:
            cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
            results.append({
                'random_state': random_state,
                'n_splits': n_splits,
                'mean_score': np.mean(scores),
                'std_score': np.std(scores),
                'all_scores': scores
            })

    df_results = pd.DataFrame(results)
    df_results.sort_values(by='mean_score', ascending=False, inplace=True)
    return df_results

# %%
# best_results = search_best_cv_scores(model, X_train_clean, y_train,
#                                     random_states=[0, 1, 42, 2024, 2025],
#                                     n_splits_list=[5, 7, 10],
#                                      )

# # Voir les 3 meilleures combinaisons
# print(best_results.head(3))

# %%
# best_results

# %%
# BestResults = search_best_cv_scores(model, X_train_clean, y_train,
#                                     random_states=range(0, 200, 15),
#                                     n_splits_list=[5, 7, 10],
#                                      )

# %%
# BestResults

# %%
# from sklearn.metrics import roc_curve, auc
# import matplotlib.pyplot as plt

# # 1. Prédire les probabilités pour la classe positive (1)
# y_prob = model.predict_proba(X_test)[:, 1]

# # 2. Calcul des points ROC
# fpr, tpr, thresholds = roc_curve(y_test, y_prob)
# roc_auc = auc(fpr, tpr)

# # 3. Tracer la courbe ROC
# plt.figure(figsize=(8, 6))
# plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}', color='blue')
# plt.plot([0, 1], [0, 1], 'k--', label='Random classifier')
# plt.xlabel('Taux de Faux Positifs (FPR)')
# plt.ylabel('Taux de Vrais Positifs (TPR)')
# plt.title('Courbe ROC - Random Forest')
# plt.legend(loc='lower right')
# plt.grid(True)
# plt.show()

# %%
# #@title modelisation 2
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state=2056,
#                                 n_estimators=100,
#                                 criterion='gini',
#                                 max_depth=None,
#                                 min_samples_split=2,
#                                 min_samples_leaf=1)
# model2.fit(X_train, y_train)


# y_pred = model2.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')  # pour ne pas afficher les warnings

def optimiser_random_forest(X, y, param_grid, cv_splits=5, scoring='f1_macro', random_states=[42]):
    """
    Teste plusieurs combinaisons d'hyperparamètres et retourne les meilleurs scores.

    param_grid: dict
        Dictionnaire des hyperparamètres à tester (valeurs sous forme de liste)
    random_states: list
        Liste des random_state à tester
    """
    results = []

    # Générer toutes les combinaisons possibles
    from itertools import product
    keys = list(param_grid.keys())
    values = list(param_grid.values())
    combos = list(product(*values))

    for rs in random_states:
        for combo in combos:
            params = dict(zip(keys, combo))
            model = RandomForestClassifier(random_state=rs, **params)
            cv = StratifiedKFold(n_splits=cv_splits, shuffle=True, random_state=rs)
            scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)

            results.append({
                **params,
                'random_state': rs,
                'mean_score': np.mean(scores),
                'std_score': np.std(scores)
            })

    return pd.DataFrame(results).sort_values(by='mean_score', ascending=False).reset_index(drop=True)

# %%
param_grid = {
    'n_estimators': [30,50],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [None],
    'min_samples_split': [10, 20],
    'min_samples_leaf': [1,3],
}

Results0 = optimiser_random_forest(X_train, y_train, param_grid,
                                  cv_splits=5,
                                  scoring='f1_macro',
                                  random_states=np.random.randint(low=0, high=2000 + 1, size=10))

Results0
# Out:
#      n_estimators criterion max_depth  min_samples_split  min_samples_leaf  \
# 0              30      gini      None                 10                 3
# 1              30      gini      None                 10                 1
# 2              50  log_loss      None                 10                 1
# 3              50   entropy      None                 10                 1
# 4              50      gini      None                 10                 3
# ..            ...       ...       ...                ...               ...
# 235            50      gini      None                 20                 3
# 236            30  log_loss      None                 20                 1
# 237            30   entropy      None                 20                 1
# 238            50      gini      None                 20                 1
# 239            30      gini      None                 20                 1
#
#      random_state  mean_score  std_score
# ...

# %%
Results0.to_excel('modelParams2(E1).xlsx')

# %%
#@title BestModel
modelF = RandomForestClassifier(random_state=435,
                                n_estimators=30,
                                criterion='entropy',
                                max_depth=None,
                                min_samples_split=20,
                                min_samples_leaf=1)
modelF.fit(X_train, y_train)


y_predF = modelF.predict(X_test)
print(confusion_matrix(y_test, y_predF))
print(classification_report(y_test, y_predF))
# Out:
# [[8 2]
#  [3 7]]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.80      0.76        10
#          1.0       0.78      0.70      0.74        10
#
#     accuracy                           0.75        20
#    macro avg       0.75      0.75      0.75        20
# weighted avg       0.75      0.75      0.75        20

# %%
#@title BestModel Evaluation
BestReF = search_best_cv_scores(modelF, X_train_clean, y_train,
                                    random_states=[0, 1, 42, 2024, 2025],
                                    n_splits_list=[5, 7, 10],
                                     )

# %%
BestReF
# Out:
#     random_state  n_splits  mean_score  std_score  \
# 9           2024         5    0.892768   0.091571
# 11          2024        10    0.881746   0.088676
# 3              1         5    0.866429   0.073030
# 6             42         5    0.866092   0.108105
# 13          2025         7    0.840504   0.106744
# 5              1        10    0.839048   0.112051
# 14          2025        10    0.836865   0.102635
# 2              0        10    0.829603   0.165766
# 4              1         7    0.825627   0.091160
# 8             42        10    0.821032   0.153931
# 7             42         7    0.806140   0.116653
# 0              0         5    0.800908   0.075217
# 1              0         7    0.800205   0.198689
# 10          2024         7    0.788420   0.179646
# 12          2025         5    0.786935   0.049141
#
#                                            all_scores
# 9   [0.9372549019607843, 0.7321428571428572, 0.861...
# ...

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# 1. Prédire les probabilités pour la classe positive (1)
y_probF = modelF.predict_proba(X_test)[:, 1]

# 2. Calcul des points ROC
fpr, tpr, thresholds = roc_curve(y_test, y_probF)
roc_auc = auc(fpr, tpr)

# 3. Tracer la courbe ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}', color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random classifier')
plt.xlabel('Taux de Faux Positifs (FPR)')
plt.ylabel('Taux de Vrais Positifs (TPR)')
plt.title('Courbe ROC - Random Forest2')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

y_scores = modelF.predict_proba(X_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)
avg_precision = average_precision_score(y_test, y_scores)

plt.figure(figsize=(8,6))
plt.plot(recall, precision, label=f'AP = {avg_precision:.2f}', color='green')
plt.xlabel('Rappel')
plt.ylabel('Précision')
plt.title('Courbe Précision-Rappel')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# Tri des scores
y_prob = modelF.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize=(8, 6))
plt.plot(tpr, label='Vrais positifs cumulés')
plt.plot(np.linspace(0, 1, len(tpr)), '--', label='Modèle aléatoire')
plt.title("Courbe des gains cumulés")
plt.xlabel("Proportion des données")
plt.ylabel("Proportion des vrais positifs")
plt.legend()
plt.grid(True)
plt.show()

# %%
importances = modelF.feature_importances_
features = X_train.columns if hasattr(X_train, 'columns') else [f'Var{i}' for i in range(X_train.shape[1])]
sorted_idx = np.argsort(importances)[::-1]

plt.figure(figsize=(10,6))
sns.barplot(x=importances[sorted_idx][:10], y=np.array(features)[sorted_idx][:10])
plt.title("Top 10 des variables importantes")
plt.xlabel("Importance")
plt.ylabel("Variable")
plt.show()

# %%
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt
import numpy as np

def plot_lift_curve(y_true, y_proba, title='Courbe de levier'):
    y_true = np.array(y_true)
    y_proba = np.array(y_proba)

    # Tri selon la probabilité décroissante
    sorted_indices = np.argsort(y_proba)[::-1]
    y_true_sorted = y_true[sorted_indices]

    # Cumul des vrais positifs
    cumulative_positives = np.cumsum(y_true_sorted)

    # Taux de levier = nb de positifs captés / positifs attendus aléatoirement
    percentages = np.arange(1, len(y_true_sorted)+1) / len(y_true_sorted)
    expected_positives = percentages * sum(y_true_sorted)
    lift = cumulative_positives / expected_positives

    plt.figure(figsize=(8, 6))
    plt.plot(percentages * 100, lift, label='Modèle', color='darkblue')
    plt.axhline(y=1, color='orange', linestyle='--', label='Modèle aléatoire')
    plt.xlabel("Pourcentage des données")
    plt.ylabel("Lift (gain par rapport au hasard)")
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.show()

# %%
y_proba = modelF.predict_proba(X_test)[:, 1]
plot_lift_curve(y_test, y_proba)

# %%
from sklearn.calibration import calibration_curve

def plot_calibration_curve(y_true, y_proba, n_bins=10):
    prob_true, prob_pred = calibration_curve(y_true, y_proba, n_bins=n_bins)

    plt.figure(figsize=(8, 6))
    plt.plot(prob_pred, prob_true, marker='o', label='Modèle')
    plt.plot([0, 1], [0, 1], linestyle='--', label='Modèle parfait', color='gray')
    plt.xlabel("Probabilité prédite")
    plt.ylabel("Probabilité observée")
    plt.title("Courbe de calibration")
    plt.legend()
    plt.grid()
    plt.show()

# %%
plot_calibration_curve(y_test, y_proba)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrix(y_true, y_pred, labels=[0, 1]):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Prédictions')
    plt.ylabel('Véritables')
    plt.title('Matrice de confusion')
    plt.show()

# %%
y_pred = modelF.predict(X_test)
plot_confusion_matrix(y_test, y_pred)
